# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
metrics = {'rule_16ngram_4clusters': {'mal_count': 65, 'ben_count': 581, 'tp': 65, 'fp': 581, 'tn': 1, 'fn': 1, 'accuracy': 0.10185185185185185, 'precision': 0.10061919504643962, 'recall': 0.9848484848484849, 'f1': 0.18258426966292132}, 'rule_64ngram_4clusters': {'mal_count': 65, 'ben_count': 581, 'tp': 65, 'fp': 581, 'tn': 1, 'fn': 1, 'accuracy': 0.10185185185185185, 'precision': 0.10061919504643962, 'recall': 0.9848484848484849, 'f1': 0.18258426966292132}, 'rule_256ngram_4clusters': {'mal_count': 65, 'ben_count': 581, 'tp': 65, 'fp': 581, 'tn': 1, 'fn': 1, 'accuracy': 0.10185185185185185, 'precision': 0.10061919504643962, 'recall': 0.9848484848484849, 'f1': 0.18258426966292132}, 'rule_256ngram_5clusters': {'mal_count': 65, 'ben_count': 581, 'tp': 65, 'fp': 581, 'tn': 1, 'fn': 1, 'accuracy': 0.10185185185185185, 'precision': 0.10061919504643962, 'recall': 0.9848484848484849, 'f1': 0.18258426966292132}, 'rule_512ngram_5clusters': {'mal_count': 55, 'ben_count': 13, 'tp': 55, 'fp': 13, 'tn': 569, 'fn': 11, 'accuracy': 0.9629629629629629, 'precision': 0.8088235294117647, 'recall': 0.8333333333333334, 'f1': 0.8208955223880597}, 'rule_8ngram_3clusters': {'mal_count': 7, 'ben_count': 0, 'tp': 7, 'fp': 0, 'tn': 582, 'fn': 59, 'accuracy': 0.9089506172839507, 'precision': 1.0, 'recall': 0.10606060606060606, 'f1': 0.19178082191780824}, 'rule_8ngram_4clusters': {'mal_count': 7, 'ben_count': 0, 'tp': 7, 'fp': 0, 'tn': 582, 'fn': 59, 'accuracy': 0.9089506172839507, 'precision': 1.0, 'recall': 0.10606060606060606, 'f1': 0.19178082191780824}, 'rule_8ngram_5clusters': {'mal_count': 7, 'ben_count': 0, 'tp': 7, 'fp': 0, 'tn': 582, 'fn': 59, 'accuracy': 0.9089506172839507, 'precision': 1.0, 'recall': 0.10606060606060606, 'f1': 0.19178082191780824}, 'rule_16ngram_2clusters': {'mal_count': 16, 'ben_count': 0, 'tp': 16, 'fp': 0, 'tn': 582, 'fn': 50, 'accuracy': 0.9228395061728395, 'precision': 1.0, 'recall': 0.24242424242424243, 'f1': 0.3902439024390244}, 'rule_16ngram_3clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_16ngram_5clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_32ngram_2clusters': {'mal_count': 21, 'ben_count': 0, 'tp': 21, 'fp': 0, 'tn': 582, 'fn': 45, 'accuracy': 0.9305555555555556, 'precision': 1.0, 'recall': 0.3181818181818182, 'f1': 0.4827586206896552}, 'rule_32ngram_4clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_32ngram_5clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_64ngram_2clusters': {'mal_count': 16, 'ben_count': 0, 'tp': 16, 'fp': 0, 'tn': 582, 'fn': 50, 'accuracy': 0.9228395061728395, 'precision': 1.0, 'recall': 0.24242424242424243, 'f1': 0.3902439024390244}, 'rule_64ngram_3clusters': {'mal_count': 20, 'ben_count': 0, 'tp': 20, 'fp': 0, 'tn': 582, 'fn': 46, 'accuracy': 0.9290123456790124, 'precision': 1.0, 'recall': 0.30303030303030304, 'f1': 0.4651162790697675}, 'rule_64ngram_5clusters': {'mal_count': 20, 'ben_count': 0, 'tp': 20, 'fp': 0, 'tn': 582, 'fn': 46, 'accuracy': 0.9290123456790124, 'precision': 1.0, 'recall': 0.30303030303030304, 'f1': 0.4651162790697675}, 'rule_128ngram_2clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_128ngram_3clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_128ngram_4clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_128ngram_5clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_256ngram_2clusters': {'mal_count': 42, 'ben_count': 0, 'tp': 42, 'fp': 0, 'tn': 582, 'fn': 24, 'accuracy': 0.9629629629629629, 'precision': 1.0, 'recall': 0.6363636363636364, 'f1': 0.7777777777777778}, 'rule_256ngram_3clusters': {'mal_count': 16, 'ben_count': 0, 'tp': 16, 'fp': 0, 'tn': 582, 'fn': 50, 'accuracy': 0.9228395061728395, 'precision': 1.0, 'recall': 0.24242424242424243, 'f1': 0.3902439024390244}, 'rule_512ngram_3clusters': {'mal_count': 55, 'ben_count': 0, 'tp': 55, 'fp': 0, 'tn': 582, 'fn': 11, 'accuracy': 0.9830246913580247, 'precision': 1.0, 'recall': 0.8333333333333334, 'f1': 0.9090909090909091}, 'rule_512ngram_4clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_1024ngram_2clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_1024ngram_3clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_1024ngram_4clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_1024ngram_5clusters': {'mal_count': 17, 'ben_count': 0, 'tp': 17, 'fp': 0, 'tn': 582, 'fn': 49, 'accuracy': 0.9243827160493827, 'precision': 1.0, 'recall': 0.25757575757575757, 'f1': 0.40963855421686746}, 'rule_512ngram_2clusters': {'mal_count': 38, 'ben_count': 0, 'tp': 38, 'fp': 0, 'tn': 582, 'fn': 28, 'accuracy': 0.9567901234567902, 'precision': 1.0, 'recall': 0.5757575757575758, 'f1': 0.7307692307692308}, 'rule_8ngram_2clusters': {'mal_count': 9, 'ben_count': 0, 'tp': 9, 'fp': 0, 'tn': 582, 'fn': 57, 'accuracy': 0.9120370370370371, 'precision': 1.0, 'recall': 0.13636363636363635, 'f1': 0.24000000000000002}}

# %%
metrics_df = pd.DataFrame.from_dict(metrics)

# %%
metrics_df.columns
# Out:
# Index(['rule_16ngram_4clusters', 'rule_64ngram_4clusters',
#        'rule_256ngram_4clusters', 'rule_256ngram_5clusters',
#        'rule_512ngram_5clusters', 'rule_8ngram_3clusters',
#        'rule_8ngram_4clusters', 'rule_8ngram_5clusters',
#        'rule_16ngram_2clusters', 'rule_16ngram_3clusters',
#        'rule_16ngram_5clusters', 'rule_32ngram_2clusters',
#        'rule_32ngram_4clusters', 'rule_32ngram_5clusters',
#        'rule_64ngram_2clusters', 'rule_64ngram_3clusters',
#        'rule_64ngram_5clusters', 'rule_128ngram_2clusters',
#        'rule_128ngram_3clusters', 'rule_128ngram_4clusters',
#        'rule_128ngram_5clusters', 'rule_256ngram_2clusters',
#        'rule_256ngram_3clusters', 'rule_512ngram_3clusters',
#        'rule_512ngram_4clusters', 'rule_1024ngram_2clusters',
#        'rule_1024ngram_3clusters', 'rule_1024ngram_4clusters',
#        'rule_1024ngram_5clusters', 'rule_512ngram_2clusters',
#        'rule_8ngram_2clusters'],
#       dtype='object')

# %%
metrics_df.index.name = 'METRICS'

# %%
metrics_df_512 = metrics_df[['rule_512ngram_2clusters', 'rule_512ngram_3clusters', 'rule_512ngram_4clusters', 'rule_512ngram_5clusters']]

# %%
metrics_df_512
# Out:
#            rule_512ngram_2clusters  rule_512ngram_3clusters  \
# METRICS
# mal_count                38.000000                55.000000
# ben_count                 0.000000                 0.000000
# tp                       38.000000                55.000000
# fp                        0.000000                 0.000000
# tn                      582.000000               582.000000
# fn                       28.000000                11.000000
# accuracy                  0.956790                 0.983025
# precision                 1.000000                 1.000000
# recall                    0.575758                 0.833333
# f1                        0.730769                 0.909091
#
#            rule_512ngram_4clusters  rule_512ngram_5clusters
# METRICS
# mal_count                17.000000                55.000000
# ben_count                 0.000000                13.000000
# tp                       17.000000                55.000000
# ...

# %%
precision = metrics_df_512.loc[['precision']].values

# %%
recall = metrics_df_512.loc[['recall']].values

# %%
recall
# Out:
# array([[0.57575758, 0.83333333, 0.25757576, 0.83333333]])

# %%
plt.scatter(precision[0], recall[0])

# plot with precision[0] and recall[0] data
plt.plot(precision[0], recall[0])

# %%
metrics_df.head()
# Out:
#            rule_16ngram_4clusters  rule_64ngram_4clusters  \
# mal_count                    65.0                    65.0
# ben_count                   581.0                   581.0
# tp                           65.0                    65.0
# fp                          581.0                   581.0
# tn                         -515.0                  -515.0
#
#            rule_256ngram_4clusters  rule_256ngram_5clusters  \
# mal_count                     65.0                     65.0
# ben_count                    581.0                    581.0
# tp                            65.0                     65.0
# fp                           581.0                    581.0
# tn                          -515.0                   -515.0
#
#            rule_512ngram_5clusters  rule_8ngram_3clusters  \
# mal_count                     55.0                    7.0
# ben_count                     13.0                    0.0
# tp                            55.0                    7.0
# ...
